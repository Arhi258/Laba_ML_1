# %%
from google.colab import drive
import os

drive.mount('/content/drive')

if os.path.exists('/content/drive/My Drive'):
    print("Диск успешно подключен!")
    print("Файлы на вашем диске:")
    # !ls "/content/drive/My Drive"
# Out:
# Mounted at /content/drive
# Диск успешно подключен!
# Файлы на вашем диске:
#  284.jpg
#  286.jpg
#  290.jpg
#  291.jpg
#  292.jpg
#  2.jpg
# 'aq7L87P_460swp.webp (460×690)'
#  Classroom
# 'Colab Notebooks'
#  IMG_20200427_201601.jpg
#  IMG_20200427_201624.jpg
#  IMG_20200427_201640.jpg
#  IMG_20200501_152244.jpg
#  IMG_20200501_152259.jpg
#  IMG_20200501_152309.jpg
#  IMG_20200508_173804.jpg
#  IMG_20200508_173824.jpg
#  IMG_20200508_173839.jpg
#  IMG_20200515_200030.jpg
#  IMG_20200515_200042.jpg
#  IMG_20200515_200050.jpg
#  IMG_20200515_200056.jpg
# 'vid_720p (2).mp4'
# 'Артемий Грабарь - Задача 10.gdraw'
# 'Артемий Грабарь - Задача 11.gdraw'
# 'Артемий Грабарь - Задача 5.gdraw'
# 'Артемий Грабарь - Задача 6.gdraw'
# 'Артемий Грабарь - Задача 7.gdraw'
# 'Артемий Грабарь - Задача 8.gdraw'
# 'Артемий Грабарь - Итоговая работа алгебра 7 класс.gslides'
# 'Артемий Грабарь - Итоговая работа геометрия 7 класс.gslides'
# ...

# %%
path_txt = "/content/drive/My Drive/my_text_file.txt"

f = open(path_txt, 'w', encoding='utf-8')
f.write("Привет из Google Colab!\n")
f.write("Это вторая строка.\n")
f.write("Файл сохранен прямо на Google Диск.")
f.close()

print(f"Файл сохранен по пути: {path_txt}")
# Out:
# Файл сохранен по пути: /content/drive/My Drive/my_text_file.txt

# %%
f = open(path_txt, 'r', encoding='utf-8')
content = f.read()
print("Содержимое считанного файла:")
print(content)
f.close()
# Out:
# Содержимое считанного файла:
# Привет из Google Colab!
# Это вторая строка.
# Файл сохранен прямо на Google Диск.

# %%
path_csv = "/content/drive/My Drive/students.csv"

students_list = [
    "Имя,Фамилия,Возраст,Группа\n",
    "Артемий,Грабарь,19,ИВТ-б-о-24-1\n",
    "Данил,Ромащенко,48,ИПИ-б-о-12-2\n",
    "Данил,Колбасенко,7,ИВТ-б-о-23-3\n"
]

f = open(path_csv, 'w', encoding='utf-8')
f.writelines(students_list)
f.close()

print(f"CSV-файл со студентами создан: {path_csv}")
# !cat "/content/drive/My Drive/students.csv"
# Out:
# CSV-файл со студентами создан: /content/drive/My Drive/students.csv
# Имя,Фамилия,Возраст,Группа
# Артемий,Грабарь,19,ИВТ-б-о-24-1
# Данил,Ромащенко,48,ИПИ-б-о-12-2
# Данил,Колбасенко,7,ИВТ-б-о-23-3
