# %%
# !dir
# Out:
#  Том в устройстве C имеет метку System
#  Серийный номер тома: 04B4-C0B5
#
#  Содержимое папки C:\Users\arhi2\anaconda_projects\bd5d6422-15f0-42cb-bdc9-43cb88998ee8
#
# 15.03.2026  15:54    <DIR>          .
# 14.03.2026  14:48    <DIR>          ..
# 15.03.2026  15:52    <DIR>          .ipynb_checkpoints
# 14.03.2026  15:09            24 516 Example_1.ipynb
# 14.03.2026  16:13             1 207 Example_2.ipynb
# 14.03.2026  15:50            40 759 Example_3.ipynb
# 14.03.2026  15:54             1 013 Example_4.ipynb
# 14.03.2026  20:26    <DIR>          Images
# 15.03.2026  15:48               111 script.py
# 14.03.2026  20:28             1 115 task_1.ipynb
# 14.03.2026  20:32             1 404 task_2.ipynb
# 15.03.2026  15:29             2 991 task_3.ipynb
# 15.03.2026  15:50             9 802 task_4.ipynb
# 15.03.2026  15:54               628 task_5.ipynb
#               10 файлов         83 546 байт
#                4 папок  55 919 665 152 байт свободно

# %%
# !where python
# Out:
# Z:\Anaconda\python.exe

# %%
# !mkdir test_folder
# !dir test_folder
# Out:
# Подпапка или файл test_folder уже существует.
#  Том в устройстве C имеет метку System
#  Серийный номер тома: 04B4-C0B5
#
#  Содержимое папки C:\Users\arhi2\anaconda_projects\bd5d6422-15f0-42cb-bdc9-43cb88998ee8\test_folder
#
# 15.03.2026  15:56    <DIR>          .
# 15.03.2026  15:57    <DIR>          ..
#                0 файлов              0 байт
#                2 папок  55 915 921 408 байт свободно

# %%
# !move script.py test_folder
# !dir test_folder 
# !del test_folder\script.py
# !rmdir test_folder
# Out:
# Перемещено файлов:         1.
#  Том в устройстве C имеет метку System
#  Серийный номер тома: 04B4-C0B5
#
#  Содержимое папки C:\Users\arhi2\anaconda_projects\bd5d6422-15f0-42cb-bdc9-43cb88998ee8\test_folder
#
# 15.03.2026  15:59    <DIR>          .
# 15.03.2026  15:59    <DIR>          ..
# 15.03.2026  15:48               111 script.py
#                1 файлов            111 байт
#                2 папок  55 918 309 376 байт свободно

# %%
from IPython.display import clear_output

print("ЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭЭ")
clear_output()
