# %%
import os

# %%
filename = "task_3.txt"
f = open(filename, 'w', encoding='utf-8')
try:
    f.write("Первая строка.\n")
    f.write("Вторая строка.\n")
    f.write("Третья строка.\n")
finally:
    f.close()
print(f"Файл {filename} создан и закрыт")
# Out:
# Файл task_3.txt создан и закрыт

# %%
f = open(filename, 'r', encoding='utf-8')
try:
    content = f.read()
    print("Содержимое файла:")
    print(content)
finally:
    f.close()
# Out:
# Содержимое файла:
# Первая строка.
# Вторая строка.
# Третья строка.

# %%
if os.path.exists(filename):
    print(f"Файл {filename} существует")

    os.remove(filename)
    print(f"Файл {filename} удален")
# Out:
# Файл task_3.txt существует
# Файл task_3.txt удален

# %%
if not os.path.exists(filename):
    print("Файл был удален, проверка завершена")
# Out:
# Файл был удален, проверка завершена
